# %%
def get_last_element(lst):
    """Prints the last element of a provided list."""
    print("🔹 The last element is: " + lst[-1])  # Accessing the last element

def get_lst():
    """Prompts the user to enter elements of the list one by one."""
    lst = []
    while True:
        elem = input("✏️ Enter an element (or press Enter to stop): ")
        if elem == "":
            break  # Stop taking input if user presses Enter
        lst.append(elem)
    return lst

def main():
    """Main function to run the program."""
    print("📋 List Input Program 📋")
    lst = get_lst()
    get_last_element(lst)

# Run the program
if __name__ == '__main__':
    main()
# Out:
# 📋 List Input Program 📋
# 🔹 The last element is: malahim
