# %%
# import random
# import tkinter as tk
# from tkinter import scrolledtext, filedialog, messagebox

# class MarkovLyricComposer:
#     def __init__(self, root):
#         self.root = root
#         self.root.title("🎵 AI Lyric Composer")
#         self.root.geometry("800x600")
        
#         # Markov chain variables
#         self.chain = {}
#         self.stickers = ["🎵", "🎤", "🎶", "✨", "🤖", "🎧", "📝", "🎼"]
        
#         # Create UI
#         self.create_widgets()
        
#         # Load some default text
#         self.load_sample_text()

#     def create_widgets(self):
#         """Create the user interface"""
#         # Main frame
#         main_frame = tk.Frame(self.root, padx=10, pady=10)
#         main_frame.pack(fill=tk.BOTH, expand=True)
        
#         # Input section
#         input_frame = tk.LabelFrame(main_frame, text="Input Text", padx=5, pady=5)
#         input_frame.pack(fill=tk.X)
        
#         self.input_text = scrolledtext.ScrolledText(input_frame, height=10, wrap=tk.WORD)
#         self.input_text.pack(fill=tk.BOTH, expand=True)
        
#         # Control buttons
#         button_frame = tk.Frame(main_frame)
#         button_frame.pack(fill=tk.X, pady=5)
        
#         tk.Button(button_frame, text="Load Text File", command=self.load_file).pack(side=tk.LEFT, padx=5)
#         tk.Button(button_frame, text="Generate Lyrics", command=self.generate_text).pack(side=tk.LEFT, padx=5)
#         tk.Button(button_frame, text="Clear", command=self.clear_text).pack(side=tk.LEFT, padx=5)
        
#         # Output section
#         output_frame = tk.LabelFrame(main_frame, text="Generated Lyrics", padx=5, pady=5)
#         output_frame.pack(fill=tk.BOTH, expand=True)
        
#         self.output_text = scrolledtext.ScrolledText(
#             output_frame, 
#             height=15, 
#             wrap=tk.WORD,
#             font=("Arial", 10),
#             bg="#f0f0f0"
#         )
#         self.output_text.pack(fill=tk.BOTH, expand=True)
        
#         # Add some decorative stickers
#         sticker_frame = tk.Frame(main_frame)
#         sticker_frame.pack(fill=tk.X, pady=5)
        
#         for sticker in self.stickers:
#             tk.Label(sticker_frame, text=sticker, font=("Arial", 20)).pack(side=tk.LEFT, padx=5)

#     def load_sample_text(self):
#         """Load some default sample text"""
#         sample_text = """I see trees of green, red roses too
# I see them bloom for me and you
# And I think to myself what a wonderful world
# I see skies of blue and clouds of white
# The bright blessed day, the dark sacred night
# And I think to myself what a wonderful world"""
#         self.input_text.insert(tk.END, sample_text)

#     def load_file(self):
#         """Load text from a file"""
#         filepath = filedialog.askopenfilename(filetypes=[("Text files", "*.txt"), ("All files", "*.*")])
#         if filepath:
#             try:
#                 with open(filepath, 'r', encoding='utf-8') as file:
#                     self.input_text.delete(1.0, tk.END)
#                     self.input_text.insert(tk.END, file.read())
#             except Exception as e:
#                 messagebox.showerror("Error", f"Could not load file: {str(e)}")

#     def clear_text(self):
#         """Clear all text"""
#         self.input_text.delete(1.0, tk.END)
#         self.output_text.delete(1.0, tk.END)

#     def build_markov_chain(self, text, chain_size=2):
#         """Build a Markov chain from the input text"""
#         words = text.split()
#         self.chain = {}
        
#         for i in range(len(words) - chain_size):
#             current_state = ' '.join(words[i:i+chain_size])
#             next_state = words[i+chain_size]
            
#             if current_state not in self.chain:
#                 self.chain[current_state] = []
#             self.chain[current_state].append(next_state)

#     def generate_text(self, length=100):
#         """Generate new text using the Markov chain"""
#         input_text = self.input_text.get(1.0, tk.END).strip()
#         if not input_text:
#             messagebox.showwarning("Warning", "Please enter some text first!")
#             return
        
#         # Build the Markov chain
#         self.build_markov_chain(input_text)
        
#         if not self.chain:
#             messagebox.showwarning("Warning", "Not enough text to generate from!")
#             return
        
#         # Start with a random initial state
#         current_state = random.choice(list(self.chain.keys()))
#         result = current_state.split()
        
#         # Generate new words
#         for _ in range(length):
#             if current_state not in self.chain:
#                 break
            
#             next_word = random.choice(self.chain[current_state])
#             result.append(next_word)
            
#             # Update current state
#             current_state = ' '.join(result[-2:])  # For chain_size=2
        
#         # Format and display the result with random stickers
#         output = ' '.join(result)
#         self.output_text.delete(1.0, tk.END)
        
#         # Add some random stickers between lines
#         lines = output.split('\n')
#         decorated_lines = []
#         for line in lines:
#             if line.strip() and random.random() > 0.7:  # 30% chance to add sticker
#                 sticker = random.choice(self.stickers)
#                 decorated_lines.append(f"{line} {sticker}")
#             else:
#                 decorated_lines.append(line)
        
#         self.output_text.insert(tk.END, '\n'.join(decorated_lines))

# # Run the application
# if __name__ == "__main__":
#     root = tk.Tk()
#     app = MarkovLyricComposer(root)
#     root.mainloop()


x=5/2
y=5//2
print(x,y)
# Out:
# 2.5 2
